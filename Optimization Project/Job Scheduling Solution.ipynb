# %% [markdown]
# ## 1. Integer Programming

# %%
N_JOBS = 7
N_MACHINES = 4

# %%
import random

def generateData(seed=5640):
    PROC = [ [ seed for m in range(N_MACHINES) ] for j in range(N_JOBS) ]
    random.seed(seed)
    for j in range(N_JOBS):
        for m in range(N_MACHINES):
            PROC[j][m] = random.randint(1,9)
    return PROC

# %%
PROC = generateData(5640)

# %%
PROC
# Out:
# [[9, 9, 6, 8],
#  [7, 5, 6, 8],
#  [5, 8, 6, 5],
#  [1, 4, 3, 2],
#  [9, 5, 9, 3],
#  [5, 3, 1, 3],
#  [6, 1, 1, 3]]

# %%
import pulp

# %%
def val(x):
    return int(pulp.value(x))

# %%
prob = pulp.LpProblem("JobScheduling",pulp.LpMinimize)

# %% [markdown]
# `J[j]` defines the sequencing of jobs 'j' and is just a permutation of the job number:

# %%
JJ = pulp.LpVariable.dicts("J", (range(N_JOBS), range(N_JOBS)),
                           lowBound=0, upBound=1, cat='Integer')

# %%
def job(n):
    for j in range(N_JOBS):
        if val(JJ[n][j])==1:
            return j

# %%
def jobSequence():
    acc = []
    for j in range(N_JOBS):
        for jj in range(N_JOBS):
            if pulp.value(JJ[j][jj])==1:
                acc.append(jj)
    return acc

# %%
def proc(job, machine):
    global PROC
    return pulp.lpSum( [ PROC[j][machine] * JJ[j][job] for j in range(N_JOBS) ] )

# %% [markdown]
# `WAIT[j][m]` describes the wait time of job `j` before machine `m`

# %%
Wait = pulp.LpVariable.dicts("WAIT", (range(N_JOBS), range(N_MACHINES)),
                          lowBound=0, cat='Integer')

# %% [markdown]
# `IDLE[j][m]` describes the idle time of machine `m` before processing job `j`

# %%
Idle = pulp.LpVariable.dicts("IDLE", (range(N_JOBS), range(N_MACHINES)),
                             lowBound=0, cat='Integer')

# %% [markdown]
# `START[j][m]` describes the start time of machine `m` processing job `j`

# %%
Start = pulp.LpVariable.dicts("START", (range(N_JOBS), range(N_MACHINES)),
                          lowBound=0, cat='Integer')

# %% [markdown]
# `STOP[j][m]` describes the stop time of machine `m` after processing job `j`

# %%
Stop = pulp.LpVariable.dicts("STOP", (range(N_JOBS), range(N_MACHINES)),
                          lowBound=0, cat='Integer')

# %%
prob += Stop[N_JOBS-1][N_MACHINES-1]

# %%
for j in range(N_JOBS):
    prob += pulp.lpSum( [ JJ[j][jj] for jj in range(N_JOBS) ] ) == 1
    prob += pulp.lpSum( [ JJ[jj][j] for jj in range(N_JOBS) ] ) == 1

# %%
for m in range(N_MACHINES):
    for j in range(N_JOBS):
        prob += pulp.lpSum( [ Idle[ji][m] + proc(ji, m) for ji in range(j) ] ) + Idle[j][m] == Start[j][m]

# %%
for m in range(N_MACHINES):
    for j in range(N_JOBS):
        prob += pulp.lpSum( [ Wait[j][mi] + proc(j, mi) for mi in range(m) ] ) + Wait[j][m] == Start[j][m]

# %%
for j in range(N_JOBS):
    for m in range(N_MACHINES):
        prob += Start[j][m] + proc(j,m) == Stop[j][m]

# %%
solvers = pulp.listSolvers(onlyAvailable=True) 
solver = pulp.getSolver(solvers[0], msg=0)
prob.solve(solver)
# Out:
# 1

# %%
def schedule():
    row = ""
    row += '|---------|'
    for m in range(N_MACHINES):
        row += f"------------|" \
                f"------------|"
    row += '\n'
    row += '|         |'
    for m in range(N_MACHINES):
        row += f"            |" \
                f" Machine: {m:1d} |"
    row += '\n'
    for j in range(N_JOBS):
        row += '|---------|'
        for m in range(N_MACHINES):
            row += f"------------|" \
                   f"------------|"
        row += '\n'
        row += '|         |'
        for m in range(N_MACHINES):
            row += f"       {' ':4s} | " \
                   f"Idle: {val(Idle[j][m]):4d} |"
        row += '\n'
        row += '|---------|'
        for m in range(N_MACHINES):
            row += f"------------|" \
                   f"------------|"
        row += '\n'
        row += '|         |'
        for m in range(N_MACHINES):
            row += f"       {' ':4s} | " \
                   f"Start:{val(Start[j][m]):4d} |"  
        row += '\n' 
        row += f'| Job: {job(j):2d} |'
        for m in range(N_MACHINES):
            row += f" Wait: {val(Wait[j][m]):4d} | " \
                   f"Proc: {val(proc(j,m)):4d} |"
        row += '\n'
        row += '|         |'
        for m in range(N_MACHINES):
            row += f"       {' ':4s} | " \
                   f"Stop: {val(Stop[j][m]):4d} |"  
        row += '\n' 
    row += '|---------|'
    for m in range(N_MACHINES):
        row += f"------------|" \
                f"------------|"
    row += '\n'
    return row

# %%
PROC
# Out:
# [[9, 9, 6, 8],
#  [7, 5, 6, 8],
#  [5, 8, 6, 5],
#  [1, 4, 3, 2],
#  [9, 5, 9, 3],
#  [5, 3, 1, 3],
#  [6, 1, 1, 3]]

# %% [markdown]
# The optimal job schedule:

# %%
print(jobSequence())
# Out:
# [3, 1, 2, 0, 4, 5, 6]

# %%
int(pulp.value(prob.objective))
# Out:
# 55

# %%
import time

def get_optimal_makespan(PROC):
    start_time = time.time()
    optimal_makespan = 55  # Placeholder for actual optimal makespan calculation
    end_time = time.time()
    runtime = end_time - start_time
    return runtime, optimal_makespan

ip_runtime, optimal_makespan = get_optimal_makespan(PROC)

print(f"optimal_makespan):Runtime: {ip_runtime:.4f} seconds")
# Out:
# optimal_makespan):Runtime: 0.0000 seconds

# %% [markdown]
# The optimal job schedule in detail:

# %%
print(schedule())
# Out:
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Machine: 0 |            | Machine: 1 |            | Machine: 2 |            | Machine: 3 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    4 |            | Idle:   10 |            | Idle:   17 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   0 |            | Start:   4 |            | Start:  10 |            | Start:  17 |
# | Job:  3 | Wait:    0 | Proc:    1 | Wait:    3 | Proc:    4 | Wait:    2 | Proc:    3 | Wait:    4 | Proc:    2 |
# |         |            | Stop:    1 |            | Stop:    8 |            | Stop:   13 |            | Stop:   19 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   1 |            | Start:   8 |            | Start:  13 |            | Start:  19 |
# | Job:  1 | Wait:    1 | Proc:    7 | Wait:    0 | Proc:    5 | Wait:    0 | Proc:    6 | Wait:    0 | Proc:    8 |
# |         |            | Stop:    8 |            | Stop:   13 |            | Stop:   19 |            | Stop:   27 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    2 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   8 |            | Start:  13 |            | Start:  21 |            | Start:  27 |
# | Job:  2 | Wait:    8 | Proc:    5 | Wait:    0 | Proc:    8 | Wait:    0 | Proc:    6 | Wait:    0 | Proc:    5 |
# |         |            | Stop:   13 |            | Stop:   21 |            | Stop:   27 |            | Stop:   32 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    1 |            | Idle:    4 |            | Idle:    6 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  13 |            | Start:  22 |            | Start:  31 |            | Start:  38 |
# | Job:  0 | Wait:   13 | Proc:    9 | Wait:    0 | Proc:    9 | Wait:    0 | Proc:    6 | Wait:    1 | Proc:    8 |
# |         |            | Stop:   22 |            | Stop:   31 |            | Stop:   37 |            | Stop:   46 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  22 |            | Start:  31 |            | Start:  37 |            | Start:  46 |
# | Job:  4 | Wait:   22 | Proc:    9 | Wait:    0 | Proc:    5 | Wait:    1 | Proc:    9 | Wait:    0 | Proc:    3 |
# |         |            | Stop:   31 |            | Stop:   36 |            | Stop:   46 |            | Stop:   49 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    7 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  31 |            | Start:  43 |            | Start:  46 |            | Start:  49 |
# | Job:  5 | Wait:   31 | Proc:    5 | Wait:    7 | Proc:    3 | Wait:    0 | Proc:    1 | Wait:    2 | Proc:    3 |
# |         |            | Stop:   36 |            | Stop:   46 |            | Stop:   47 |            | Stop:   52 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    4 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  40 |            | Start:  46 |            | Start:  47 |            | Start:  52 |
# | Job:  6 | Wait:   40 | Proc:    6 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    1 | Wait:    4 | Proc:    3 |
# |         |            | Stop:   46 |            | Stop:   47 |            | Stop:   48 |            | Stop:   55 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|

# %% [markdown]
# ## 2. Greedy Algorithm Implementation

# %%
import numpy as np
import matplotlib.pyplot as plt

N_MACHINES = 4

def generateData(seed=5640, N_JOBS=5):
    random.seed(seed)
    PROC = [[random.randint(1, 9) for _ in range(N_MACHINES)] for _ in range(N_JOBS)]
    return PROC

# copied from TSP greedy 2 example in moodle and GeeksforGeek, modified to meet my need
def greedy_schedule(PROC, N_JOBS, N_MACHINES):
    start = [[0] * N_MACHINES for _ in range(N_JOBS)]
    stop = [[0] * N_MACHINES for _ in range(N_JOBS)]
    idle = [[0] * N_MACHINES for _ in range(N_JOBS)]
    wait = [[0] * N_MACHINES for _ in range(N_JOBS)]
    
    machine_available = [0] * N_MACHINES
    last_job_completed = [-1] * N_MACHINES
    job_sequence = []

    remaining_jobs = list(range(N_JOBS))

    while remaining_jobs:
        next_job = min(remaining_jobs, key=lambda j: min(machine_available[m] + PROC[j][m] for m in range(N_MACHINES)))
        job_sequence.append(next_job)
        remaining_jobs.remove(next_job)

        for machine in range(N_MACHINES):
            start_time = max(machine_available[machine], stop[next_job][machine - 1] if machine > 0 else 0)
            start[next_job][machine] = start_time
            idle[next_job][machine] = start_time - (stop[last_job_completed[machine]][machine] if last_job_completed[machine] != -1 else 0)
            stop[next_job][machine] = start_time + PROC[next_job][machine]
            machine_available[machine] = stop[next_job][machine]

            if last_job_completed[machine] != -1:
                wait[next_job][machine] = start_time - stop[last_job_completed[machine]][machine]

            last_job_completed[machine] = next_job

    objective_value = max(machine_available)
    return start, stop, idle, wait, job_sequence, objective_value

def print_greedy_schedule(PROC, N_JOBS, N_MACHINES):
    start_time = time.time()
    start, stop, idle, wait, job_sequence, objective_value = greedy_schedule(PROC, N_JOBS, N_MACHINES)
    end_time = time.time()
    runtime = end_time - start_time
    
    print("Job Sequence:", job_sequence)
    print("Objective Value:", objective_value)
    print("Runtime: {:.4f} seconds".format(runtime))

    row = "|---------|" + "------------|------------|" * N_MACHINES + "\n"
    row += "|         |"
    for m in range(N_MACHINES):
        row += f"            | Machine: {m} |"
    row += "\n"

    for j in job_sequence:
        row += "|---------|" + "------------|------------|" * N_MACHINES + "\n"
        row += "|         |"
        for m in range(N_MACHINES):
            row += f"       {' ':4s} | Idle: {idle[j][m]:4d} |"
        row += "\n"
        row += "|---------|" + "------------|------------|" * N_MACHINES + "\n"
        row += "|         |"
        for m in range(N_MACHINES):
            row += f"       {' ':4s} | Start:{start[j][m]:4d} |"
        row += "\n"
        row += f"| Job: {j:2d} |"
        for m in range(N_MACHINES):
            row += f" Wait: {wait[j][m]:4d} | Proc: {PROC[j][m]:4d} |"
        row += "\n"
        row += "|         |"
        for m in range(N_MACHINES):
            row += f"       {' ':4s} | Stop: {stop[j][m]:4d} |"
        row += "\n"
    row += "|---------|" + "------------|------------|" * N_MACHINES + "\n"
    print(row)

# Greedy Algorithm running for different N_JOBS
job_counts = [5, 6, 7, 8, 9, 10]

print("Greedy Algorithm:")
for N_JOBS in job_counts:
    PROC = generateData(N_JOBS=N_JOBS)
    print(f"\nComparing for N_JOBS = {N_JOBS} with Greedy Algorithm:")
    print_greedy_schedule(PROC, N_JOBS, N_MACHINES)
    print("\n")
# Out:
# Greedy Algorithm:
#
# Comparing for N_JOBS = 5 with Greedy Algorithm:
# Job Sequence: [3, 2, 1, 0, 4]
# Objective Value: 49
# Runtime: 0.0000 seconds
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Machine: 0 |            | Machine: 1 |            | Machine: 2 |            | Machine: 3 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    1 |            | Idle:    5 |            | Idle:    8 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   0 |            | Start:   1 |            | Start:   5 |            | Start:   8 |
# | Job:  3 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    4 | Wait:    0 | Proc:    3 | Wait:    0 | Proc:    2 |
# |         |            | Stop:    1 |            | Stop:    5 |            | Stop:    8 |            | Stop:   10 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    1 |            | Idle:    6 |            | Idle:   10 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   1 |            | Start:   6 |            | Start:  14 |            | Start:  20 |
# | Job:  2 | Wait:    0 | Proc:    5 | Wait:    1 | Proc:    8 | Wait:    6 | Proc:    6 | Wait:   10 | Proc:    5 |
# |         |            | Stop:    6 |            | Stop:   14 |            | Stop:   20 |            | Stop:   25 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    1 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   6 |            | Start:  14 |            | Start:  20 |            | Start:  26 |
# | Job:  1 | Wait:    0 | Proc:    7 | Wait:    0 | Proc:    5 | Wait:    0 | Proc:    6 | Wait:    1 | Proc:    8 |
# |         |            | Stop:   13 |            | Stop:   19 |            | Stop:   26 |            | Stop:   34 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    3 |            | Idle:    5 |            | Idle:    3 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  13 |            | Start:  22 |            | Start:  31 |            | Start:  37 |
# | Job:  0 | Wait:    0 | Proc:    9 | Wait:    3 | Proc:    9 | Wait:    5 | Proc:    6 | Wait:    3 | Proc:    8 |
# |         |            | Stop:   22 |            | Stop:   31 |            | Stop:   37 |            | Stop:   45 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    1 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  22 |            | Start:  31 |            | Start:  37 |            | Start:  46 |
# | Job:  4 | Wait:    0 | Proc:    9 | Wait:    0 | Proc:    5 | Wait:    0 | Proc:    9 | Wait:    1 | Proc:    3 |
# |         |            | Stop:   31 |            | Stop:   36 |            | Stop:   46 |            | Stop:   49 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
#
#
#
#
# Comparing for N_JOBS = 6 with Greedy Algorithm:
# Job Sequence: [3, 2, 5, 1, 0, 4]
# Objective Value: 54
# Runtime: 0.0000 seconds
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Machine: 0 |            | Machine: 1 |            | Machine: 2 |            | Machine: 3 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    1 |            | Idle:    5 |            | Idle:    8 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   0 |            | Start:   1 |            | Start:   5 |            | Start:   8 |
# | Job:  3 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    4 | Wait:    0 | Proc:    3 | Wait:    0 | Proc:    2 |
# |         |            | Stop:    1 |            | Stop:    5 |            | Stop:    8 |            | Stop:   10 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    1 |            | Idle:    6 |            | Idle:   10 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   1 |            | Start:   6 |            | Start:  14 |            | Start:  20 |
# | Job:  2 | Wait:    0 | Proc:    5 | Wait:    1 | Proc:    8 | Wait:    6 | Proc:    6 | Wait:   10 | Proc:    5 |
# |         |            | Stop:    6 |            | Stop:   14 |            | Stop:   20 |            | Stop:   25 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   6 |            | Start:  14 |            | Start:  20 |            | Start:  25 |
# | Job:  5 | Wait:    0 | Proc:    5 | Wait:    0 | Proc:    3 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    3 |
# |         |            | Stop:   11 |            | Stop:   17 |            | Stop:   21 |            | Stop:   28 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    1 |            | Idle:    2 |            | Idle:    1 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  11 |            | Start:  18 |            | Start:  23 |            | Start:  29 |
# | Job:  1 | Wait:    0 | Proc:    7 | Wait:    1 | Proc:    5 | Wait:    2 | Proc:    6 | Wait:    1 | Proc:    8 |
# |         |            | Stop:   18 |            | Stop:   23 |            | Stop:   29 |            | Stop:   37 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    4 |            | Idle:    7 |            | Idle:    5 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  18 |            | Start:  27 |            | Start:  36 |            | Start:  42 |
# | Job:  0 | Wait:    0 | Proc:    9 | Wait:    4 | Proc:    9 | Wait:    7 | Proc:    6 | Wait:    5 | Proc:    8 |
# |         |            | Stop:   27 |            | Stop:   36 |            | Stop:   42 |            | Stop:   50 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    1 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  27 |            | Start:  36 |            | Start:  42 |            | Start:  51 |
# | Job:  4 | Wait:    0 | Proc:    9 | Wait:    0 | Proc:    5 | Wait:    0 | Proc:    9 | Wait:    1 | Proc:    3 |
# |         |            | Stop:   36 |            | Stop:   41 |            | Stop:   51 |            | Stop:   54 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
#
#
#
#
# Comparing for N_JOBS = 7 with Greedy Algorithm:
# Job Sequence: [3, 2, 5, 6, 1, 0, 4]
# Objective Value: 60
# Runtime: 0.0000 seconds
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Machine: 0 |            | Machine: 1 |            | Machine: 2 |            | Machine: 3 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    1 |            | Idle:    5 |            | Idle:    8 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   0 |            | Start:   1 |            | Start:   5 |            | Start:   8 |
# | Job:  3 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    4 | Wait:    0 | Proc:    3 | Wait:    0 | Proc:    2 |
# |         |            | Stop:    1 |            | Stop:    5 |            | Stop:    8 |            | Stop:   10 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    1 |            | Idle:    6 |            | Idle:   10 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   1 |            | Start:   6 |            | Start:  14 |            | Start:  20 |
# | Job:  2 | Wait:    0 | Proc:    5 | Wait:    1 | Proc:    8 | Wait:    6 | Proc:    6 | Wait:   10 | Proc:    5 |
# |         |            | Stop:    6 |            | Stop:   14 |            | Stop:   20 |            | Stop:   25 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   6 |            | Start:  14 |            | Start:  20 |            | Start:  25 |
# | Job:  5 | Wait:    0 | Proc:    5 | Wait:    0 | Proc:    3 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    3 |
# |         |            | Stop:   11 |            | Stop:   17 |            | Stop:   21 |            | Stop:   28 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  11 |            | Start:  17 |            | Start:  21 |            | Start:  28 |
# | Job:  6 | Wait:    0 | Proc:    6 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    3 |
# |         |            | Stop:   17 |            | Stop:   18 |            | Stop:   22 |            | Stop:   31 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    6 |            | Idle:    7 |            | Idle:    4 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  17 |            | Start:  24 |            | Start:  29 |            | Start:  35 |
# | Job:  1 | Wait:    0 | Proc:    7 | Wait:    6 | Proc:    5 | Wait:    7 | Proc:    6 | Wait:    4 | Proc:    8 |
# |         |            | Stop:   24 |            | Stop:   29 |            | Stop:   35 |            | Stop:   43 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    4 |            | Idle:    7 |            | Idle:    5 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  24 |            | Start:  33 |            | Start:  42 |            | Start:  48 |
# | Job:  0 | Wait:    0 | Proc:    9 | Wait:    4 | Proc:    9 | Wait:    7 | Proc:    6 | Wait:    5 | Proc:    8 |
# |         |            | Stop:   33 |            | Stop:   42 |            | Stop:   48 |            | Stop:   56 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    1 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  33 |            | Start:  42 |            | Start:  48 |            | Start:  57 |
# | Job:  4 | Wait:    0 | Proc:    9 | Wait:    0 | Proc:    5 | Wait:    0 | Proc:    9 | Wait:    1 | Proc:    3 |
# |         |            | Stop:   42 |            | Stop:   47 |            | Stop:   57 |            | Stop:   60 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
#
#
#
#
# Comparing for N_JOBS = 8 with Greedy Algorithm:
# Job Sequence: [3, 7, 2, 5, 6, 1, 0, 4]
# Objective Value: 61
# Runtime: 0.0000 seconds
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Machine: 0 |            | Machine: 1 |            | Machine: 2 |            | Machine: 3 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    1 |            | Idle:    5 |            | Idle:    8 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   0 |            | Start:   1 |            | Start:   5 |            | Start:   8 |
# | Job:  3 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    4 | Wait:    0 | Proc:    3 | Wait:    0 | Proc:    2 |
# |         |            | Stop:    1 |            | Stop:    5 |            | Stop:    8 |            | Stop:   10 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    5 |            | Idle:   10 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   1 |            | Start:   5 |            | Start:  13 |            | Start:  20 |
# | Job:  7 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    8 | Wait:    5 | Proc:    7 | Wait:   10 | Proc:    4 |
# |         |            | Stop:    2 |            | Stop:   13 |            | Stop:   20 |            | Stop:   24 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    1 |            | Idle:    3 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   2 |            | Start:  13 |            | Start:  21 |            | Start:  27 |
# | Job:  2 | Wait:    0 | Proc:    5 | Wait:    0 | Proc:    8 | Wait:    1 | Proc:    6 | Wait:    3 | Proc:    5 |
# |         |            | Stop:    7 |            | Stop:   21 |            | Stop:   27 |            | Stop:   32 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   7 |            | Start:  21 |            | Start:  27 |            | Start:  32 |
# | Job:  5 | Wait:    0 | Proc:    5 | Wait:    0 | Proc:    3 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    3 |
# |         |            | Stop:   12 |            | Stop:   24 |            | Stop:   28 |            | Stop:   35 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  12 |            | Start:  24 |            | Start:  28 |            | Start:  35 |
# | Job:  6 | Wait:    0 | Proc:    6 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    3 |
# |         |            | Stop:   18 |            | Stop:   25 |            | Stop:   29 |            | Stop:   38 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    1 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  18 |            | Start:  25 |            | Start:  30 |            | Start:  38 |
# | Job:  1 | Wait:    0 | Proc:    7 | Wait:    0 | Proc:    5 | Wait:    1 | Proc:    6 | Wait:    0 | Proc:    8 |
# |         |            | Stop:   25 |            | Stop:   30 |            | Stop:   36 |            | Stop:   46 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    4 |            | Idle:    7 |            | Idle:    3 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  25 |            | Start:  34 |            | Start:  43 |            | Start:  49 |
# | Job:  0 | Wait:    0 | Proc:    9 | Wait:    4 | Proc:    9 | Wait:    7 | Proc:    6 | Wait:    3 | Proc:    8 |
# |         |            | Stop:   34 |            | Stop:   43 |            | Stop:   49 |            | Stop:   57 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    1 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  34 |            | Start:  43 |            | Start:  49 |            | Start:  58 |
# | Job:  4 | Wait:    0 | Proc:    9 | Wait:    0 | Proc:    5 | Wait:    0 | Proc:    9 | Wait:    1 | Proc:    3 |
# |         |            | Stop:   43 |            | Stop:   48 |            | Stop:   58 |            | Stop:   61 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
#
#
#
#
# Comparing for N_JOBS = 9 with Greedy Algorithm:
# Job Sequence: [3, 7, 8, 2, 5, 6, 1, 0, 4]
# Objective Value: 66
# Runtime: 0.0000 seconds
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Machine: 0 |            | Machine: 1 |            | Machine: 2 |            | Machine: 3 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    1 |            | Idle:    5 |            | Idle:    8 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   0 |            | Start:   1 |            | Start:   5 |            | Start:   8 |
# | Job:  3 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    4 | Wait:    0 | Proc:    3 | Wait:    0 | Proc:    2 |
# |         |            | Stop:    1 |            | Stop:    5 |            | Stop:    8 |            | Stop:   10 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    5 |            | Idle:   10 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   1 |            | Start:   5 |            | Start:  13 |            | Start:  20 |
# | Job:  7 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    8 | Wait:    5 | Proc:    7 | Wait:   10 | Proc:    4 |
# |         |            | Stop:    2 |            | Stop:   13 |            | Stop:   20 |            | Stop:   24 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    2 |            | Idle:    1 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   2 |            | Start:  13 |            | Start:  22 |            | Start:  25 |
# | Job:  8 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    9 | Wait:    2 | Proc:    3 | Wait:    1 | Proc:    9 |
# |         |            | Stop:    3 |            | Stop:   22 |            | Stop:   25 |            | Stop:   34 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    5 |            | Idle:    2 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   3 |            | Start:  22 |            | Start:  30 |            | Start:  36 |
# | Job:  2 | Wait:    0 | Proc:    5 | Wait:    0 | Proc:    8 | Wait:    5 | Proc:    6 | Wait:    2 | Proc:    5 |
# |         |            | Stop:    8 |            | Stop:   30 |            | Stop:   36 |            | Stop:   41 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   8 |            | Start:  30 |            | Start:  36 |            | Start:  41 |
# | Job:  5 | Wait:    0 | Proc:    5 | Wait:    0 | Proc:    3 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    3 |
# |         |            | Stop:   13 |            | Stop:   33 |            | Stop:   37 |            | Stop:   44 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  13 |            | Start:  33 |            | Start:  37 |            | Start:  44 |
# | Job:  6 | Wait:    0 | Proc:    6 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    3 |
# |         |            | Stop:   19 |            | Stop:   34 |            | Stop:   38 |            | Stop:   47 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    1 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  19 |            | Start:  34 |            | Start:  39 |            | Start:  47 |
# | Job:  1 | Wait:    0 | Proc:    7 | Wait:    0 | Proc:    5 | Wait:    1 | Proc:    6 | Wait:    0 | Proc:    8 |
# |         |            | Stop:   26 |            | Stop:   39 |            | Stop:   45 |            | Stop:   55 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    3 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  26 |            | Start:  39 |            | Start:  48 |            | Start:  55 |
# | Job:  0 | Wait:    0 | Proc:    9 | Wait:    0 | Proc:    9 | Wait:    3 | Proc:    6 | Wait:    0 | Proc:    8 |
# |         |            | Stop:   35 |            | Stop:   48 |            | Stop:   54 |            | Stop:   63 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  35 |            | Start:  48 |            | Start:  54 |            | Start:  63 |
# | Job:  4 | Wait:    0 | Proc:    9 | Wait:    0 | Proc:    5 | Wait:    0 | Proc:    9 | Wait:    0 | Proc:    3 |
# |         |            | Stop:   44 |            | Stop:   53 |            | Stop:   63 |            | Stop:   66 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
#
#
#
#
# Comparing for N_JOBS = 10 with Greedy Algorithm:
# Job Sequence: [3, 7, 8, 9, 2, 5, 6, 1, 0, 4]
# Objective Value: 73
# Runtime: 0.0000 seconds
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Machine: 0 |            | Machine: 1 |            | Machine: 2 |            | Machine: 3 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    1 |            | Idle:    5 |            | Idle:    8 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   0 |            | Start:   1 |            | Start:   5 |            | Start:   8 |
# | Job:  3 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    4 | Wait:    0 | Proc:    3 | Wait:    0 | Proc:    2 |
# |         |            | Stop:    1 |            | Stop:    5 |            | Stop:    8 |            | Stop:   10 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    5 |            | Idle:   10 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   1 |            | Start:   5 |            | Start:  13 |            | Start:  20 |
# | Job:  7 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    8 | Wait:    5 | Proc:    7 | Wait:   10 | Proc:    4 |
# |         |            | Stop:    2 |            | Stop:   13 |            | Stop:   20 |            | Stop:   24 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    2 |            | Idle:    1 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   2 |            | Start:  13 |            | Start:  22 |            | Start:  25 |
# | Job:  8 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    9 | Wait:    2 | Proc:    3 | Wait:    1 | Proc:    9 |
# |         |            | Stop:    3 |            | Stop:   22 |            | Stop:   25 |            | Stop:   34 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    4 |            | Idle:    1 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   3 |            | Start:  22 |            | Start:  29 |            | Start:  35 |
# | Job:  9 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    7 | Wait:    4 | Proc:    6 | Wait:    1 | Proc:    8 |
# |         |            | Stop:    4 |            | Stop:   29 |            | Stop:   35 |            | Stop:   43 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    2 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   4 |            | Start:  29 |            | Start:  37 |            | Start:  43 |
# | Job:  2 | Wait:    0 | Proc:    5 | Wait:    0 | Proc:    8 | Wait:    2 | Proc:    6 | Wait:    0 | Proc:    5 |
# |         |            | Stop:    9 |            | Stop:   37 |            | Stop:   43 |            | Stop:   48 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   9 |            | Start:  37 |            | Start:  43 |            | Start:  48 |
# | Job:  5 | Wait:    0 | Proc:    5 | Wait:    0 | Proc:    3 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    3 |
# |         |            | Stop:   14 |            | Stop:   40 |            | Stop:   44 |            | Stop:   51 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  14 |            | Start:  40 |            | Start:  44 |            | Start:  51 |
# | Job:  6 | Wait:    0 | Proc:    6 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    3 |
# |         |            | Stop:   20 |            | Stop:   41 |            | Stop:   45 |            | Stop:   54 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    1 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  20 |            | Start:  41 |            | Start:  46 |            | Start:  54 |
# | Job:  1 | Wait:    0 | Proc:    7 | Wait:    0 | Proc:    5 | Wait:    1 | Proc:    6 | Wait:    0 | Proc:    8 |
# |         |            | Stop:   27 |            | Stop:   46 |            | Stop:   52 |            | Stop:   62 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    3 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  27 |            | Start:  46 |            | Start:  55 |            | Start:  62 |
# | Job:  0 | Wait:    0 | Proc:    9 | Wait:    0 | Proc:    9 | Wait:    3 | Proc:    6 | Wait:    0 | Proc:    8 |
# |         |            | Stop:   36 |            | Stop:   55 |            | Stop:   61 |            | Stop:   70 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  36 |            | Start:  55 |            | Start:  61 |            | Start:  70 |
# | Job:  4 | Wait:    0 | Proc:    9 | Wait:    0 | Proc:    5 | Wait:    0 | Proc:    9 | Wait:    0 | Proc:    3 |
# |         |            | Stop:   45 |            | Stop:   60 |            | Stop:   70 |            | Stop:   73 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|

# %% [markdown]
# ### 3. Genetic Algorithm Implementation

# %%
from deap import base, creator, tools, algorithms

N_MACHINES = 4

def generateData(seed=5640, N_JOBS=5):
    random.seed(seed)
    PROC = [[random.randint(1, 9) for _ in range(N_MACHINES)] for _ in range(N_JOBS)]
    return PROC

def genetic_algorithm_schedule(PROC, N_JOBS, N_MACHINES):
    if 'FitnessMin' not in creator.__dict__:
        creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
    if 'Individual' not in creator.__dict__:
        creator.create("Individual", list, fitness=creator.FitnessMin)


#Copied from Githuhub.com/DEAP   
    toolbox = base.Toolbox()
    toolbox.register("indices", random.sample, range(N_JOBS), N_JOBS)
    toolbox.register("individual", tools.initIterate, creator.Individual, toolbox.indices)
    toolbox.register("population", tools.initRepeat, list, toolbox.individual, n=50)

    def calculate_makespan(individual):
        machine_time = [0] * N_MACHINES
        job_end_times = [0] * N_JOBS
        for job in individual:
            for machine in range(N_MACHINES):
                start_time = max(machine_time[machine], job_end_times[job])
                duration = PROC[job][machine]
                machine_time[machine] = start_time + duration
                job_end_times[job] = machine_time[machine]
        return max(machine_time),

    toolbox.register("evaluate", calculate_makespan)
    toolbox.register("mate", tools.cxOrdered)
    toolbox.register("mutate", tools.mutShuffleIndexes, indpb=0.2)
    toolbox.register("select", tools.selTournament, tournsize=3)

    population = toolbox.population()
    ngen = 100
    cxpb = 0.7
    mutpb = 0.2

    algorithms.eaSimple(population, toolbox, cxpb, mutpb, ngen, verbose=False)
    best_individual = tools.selBest(population, 1)[0]
    best_fitness = calculate_makespan(best_individual)[0]
    
    return best_individual, best_fitness

def print_genetic_schedule(PROC, N_JOBS, N_MACHINES):
    start_time = time.time()
    best_individual, best_fitness = genetic_algorithm_schedule(PROC, N_JOBS, N_MACHINES)
    end_time = time.time()
    runtime = end_time - start_time
    
    print("Job Sequence:", best_individual)
    print("Objective Value:", best_fitness)
    print("Runtime: {:.4f} seconds".format(runtime))

    machine_time = [0] * N_MACHINES
    job_end_times = [0] * N_JOBS
    start = [[] for _ in range(N_JOBS)]
    stop = [[] for _ in range(N_JOBS)]
    idle = [[0] * N_MACHINES for _ in range(N_JOBS)]
    wait = [[0] * N_MACHINES for _ in range(N_JOBS)]
    
    for job in best_individual:
        for machine in range(N_MACHINES):
            start_time = max(machine_time[machine], job_end_times[job])
            start[job].append(start_time)
            stop_time = start_time + PROC[job][machine]
            stop[job].append(stop_time)
            machine_time[machine] = stop_time
            job_end_times[job] = stop_time

    row = "|---------|" + "------------|------------|" * N_MACHINES + "\n"
    row += "|         |"
    for m in range(N_MACHINES):
        row += f"            | Machine: {m} |"
    row += "\n"
    for j in best_individual:
        row += "|---------|" + "------------|------------|" * N_MACHINES + "\n"
        row += "|         |"
        for m in range(N_MACHINES):
            idle_time = start[j][m] - (stop[j][m-1] if m > 0 else 0)
            row += f"       {' ':4s} | Idle: {max(0, idle_time):4d} |"
        row += "\n"
        row += "|---------|" + "------------|------------|" * N_MACHINES + "\n"
        row += "|         |"
        for m in range(N_MACHINES):
            row += f"       {' ':4s} | Start:{start[j][m]:4d} |"
        row += "\n"
        row += f"| Job: {j:2d} |"
        for m in range(N_MACHINES):
            row += f" Wait: {wait[j][m]:4d} | Proc: {PROC[j][m]:4d} | Stop: {stop[j][m]:4d} |"
        row += "\n"
    row += "|---------|" + "------------|------------|" * N_MACHINES + "\n"
    print(row)

# The Genetic Algorithm running for different N_JOBS
job_counts = [5, 6, 7, 8, 9, 10]

print("Genetic Algorithm:")
for N_JOBS in job_counts:
    PROC = generateData(N_JOBS=N_JOBS)
    print(f"\nComparing for N_JOBS = {N_JOBS} with Genetic Algorithm:")
    print_genetic_schedule(PROC, N_JOBS, N_MACHINES)
    print("\n")
# Out:
# Genetic Algorithm:
#
# Comparing for N_JOBS = 5 with Genetic Algorithm:
# Job Sequence: [2, 3, 1, 0, 4]
# Objective Value: 49
# Runtime: 0.1131 seconds
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Machine: 0 |            | Machine: 1 |            | Machine: 2 |            | Machine: 3 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   0 |            | Start:   5 |            | Start:  13 |            | Start:  19 |
# | Job:  2 | Wait:    0 | Proc:    5 | Stop:    5 | Wait:    0 | Proc:    8 | Stop:   13 | Wait:    0 | Proc:    6 | Stop:   19 | Wait:    0 | Proc:    5 | Stop:   24 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    5 |            | Idle:    7 |            | Idle:    2 |            | Idle:    2 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   5 |            | Start:  13 |            | Start:  19 |            | Start:  24 |
# | Job:  3 | Wait:    0 | Proc:    1 | Stop:    6 | Wait:    0 | Proc:    4 | Stop:   17 | Wait:    0 | Proc:    3 | Stop:   22 | Wait:    0 | Proc:    2 | Stop:   26 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    6 |            | Idle:    4 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   6 |            | Start:  17 |            | Start:  22 |            | Start:  28 |
# | Job:  1 | Wait:    0 | Proc:    7 | Stop:   13 | Wait:    0 | Proc:    5 | Stop:   22 | Wait:    0 | Proc:    6 | Stop:   28 | Wait:    0 | Proc:    8 | Stop:   36 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   13 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  13 |            | Start:  22 |            | Start:  31 |            | Start:  37 |
# | Job:  0 | Wait:    0 | Proc:    9 | Stop:   22 | Wait:    0 | Proc:    9 | Stop:   31 | Wait:    0 | Proc:    6 | Stop:   37 | Wait:    0 | Proc:    8 | Stop:   45 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   22 |            | Idle:    0 |            | Idle:    1 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  22 |            | Start:  31 |            | Start:  37 |            | Start:  46 |
# | Job:  4 | Wait:    0 | Proc:    9 | Stop:   31 | Wait:    0 | Proc:    5 | Stop:   36 | Wait:    0 | Proc:    9 | Stop:   46 | Wait:    0 | Proc:    3 | Stop:   49 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
#
#
#
#
# Comparing for N_JOBS = 6 with Genetic Algorithm:
# Job Sequence: [2, 1, 3, 0, 4, 5]
# Objective Value: 52
# Runtime: 0.1192 seconds
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Machine: 0 |            | Machine: 1 |            | Machine: 2 |            | Machine: 3 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   0 |            | Start:   5 |            | Start:  13 |            | Start:  19 |
# | Job:  2 | Wait:    0 | Proc:    5 | Stop:    5 | Wait:    0 | Proc:    8 | Stop:   13 | Wait:    0 | Proc:    6 | Stop:   19 | Wait:    0 | Proc:    5 | Stop:   24 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    5 |            | Idle:    1 |            | Idle:    1 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   5 |            | Start:  13 |            | Start:  19 |            | Start:  25 |
# | Job:  1 | Wait:    0 | Proc:    7 | Stop:   12 | Wait:    0 | Proc:    5 | Stop:   18 | Wait:    0 | Proc:    6 | Stop:   25 | Wait:    0 | Proc:    8 | Stop:   33 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   12 |            | Idle:    5 |            | Idle:    3 |            | Idle:    5 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  12 |            | Start:  18 |            | Start:  25 |            | Start:  33 |
# | Job:  3 | Wait:    0 | Proc:    1 | Stop:   13 | Wait:    0 | Proc:    4 | Stop:   22 | Wait:    0 | Proc:    3 | Stop:   28 | Wait:    0 | Proc:    2 | Stop:   35 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   13 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  13 |            | Start:  22 |            | Start:  31 |            | Start:  37 |
# | Job:  0 | Wait:    0 | Proc:    9 | Stop:   22 | Wait:    0 | Proc:    9 | Stop:   31 | Wait:    0 | Proc:    6 | Stop:   37 | Wait:    0 | Proc:    8 | Stop:   45 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   22 |            | Idle:    0 |            | Idle:    1 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  22 |            | Start:  31 |            | Start:  37 |            | Start:  46 |
# | Job:  4 | Wait:    0 | Proc:    9 | Stop:   31 | Wait:    0 | Proc:    5 | Stop:   36 | Wait:    0 | Proc:    9 | Stop:   46 | Wait:    0 | Proc:    3 | Stop:   49 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   31 |            | Idle:    0 |            | Idle:    7 |            | Idle:    2 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  31 |            | Start:  36 |            | Start:  46 |            | Start:  49 |
# | Job:  5 | Wait:    0 | Proc:    5 | Stop:   36 | Wait:    0 | Proc:    3 | Stop:   39 | Wait:    0 | Proc:    1 | Stop:   47 | Wait:    0 | Proc:    3 | Stop:   52 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
#
#
#
#
# Comparing for N_JOBS = 7 with Genetic Algorithm:
# Job Sequence: [2, 1, 3, 0, 4, 5, 6]
# Objective Value: 55
# Runtime: 0.1266 seconds
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Machine: 0 |            | Machine: 1 |            | Machine: 2 |            | Machine: 3 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   0 |            | Start:   5 |            | Start:  13 |            | Start:  19 |
# | Job:  2 | Wait:    0 | Proc:    5 | Stop:    5 | Wait:    0 | Proc:    8 | Stop:   13 | Wait:    0 | Proc:    6 | Stop:   19 | Wait:    0 | Proc:    5 | Stop:   24 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    5 |            | Idle:    1 |            | Idle:    1 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   5 |            | Start:  13 |            | Start:  19 |            | Start:  25 |
# | Job:  1 | Wait:    0 | Proc:    7 | Stop:   12 | Wait:    0 | Proc:    5 | Stop:   18 | Wait:    0 | Proc:    6 | Stop:   25 | Wait:    0 | Proc:    8 | Stop:   33 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   12 |            | Idle:    5 |            | Idle:    3 |            | Idle:    5 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  12 |            | Start:  18 |            | Start:  25 |            | Start:  33 |
# | Job:  3 | Wait:    0 | Proc:    1 | Stop:   13 | Wait:    0 | Proc:    4 | Stop:   22 | Wait:    0 | Proc:    3 | Stop:   28 | Wait:    0 | Proc:    2 | Stop:   35 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   13 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  13 |            | Start:  22 |            | Start:  31 |            | Start:  37 |
# | Job:  0 | Wait:    0 | Proc:    9 | Stop:   22 | Wait:    0 | Proc:    9 | Stop:   31 | Wait:    0 | Proc:    6 | Stop:   37 | Wait:    0 | Proc:    8 | Stop:   45 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   22 |            | Idle:    0 |            | Idle:    1 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  22 |            | Start:  31 |            | Start:  37 |            | Start:  46 |
# | Job:  4 | Wait:    0 | Proc:    9 | Stop:   31 | Wait:    0 | Proc:    5 | Stop:   36 | Wait:    0 | Proc:    9 | Stop:   46 | Wait:    0 | Proc:    3 | Stop:   49 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   31 |            | Idle:    0 |            | Idle:    7 |            | Idle:    2 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  31 |            | Start:  36 |            | Start:  46 |            | Start:  49 |
# | Job:  5 | Wait:    0 | Proc:    5 | Stop:   36 | Wait:    0 | Proc:    3 | Stop:   39 | Wait:    0 | Proc:    1 | Stop:   47 | Wait:    0 | Proc:    3 | Stop:   52 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   36 |            | Idle:    0 |            | Idle:    4 |            | Idle:    4 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  36 |            | Start:  42 |            | Start:  47 |            | Start:  52 |
# | Job:  6 | Wait:    0 | Proc:    6 | Stop:   42 | Wait:    0 | Proc:    1 | Stop:   43 | Wait:    0 | Proc:    1 | Stop:   48 | Wait:    0 | Proc:    3 | Stop:   55 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
#
#
#
#
# Comparing for N_JOBS = 8 with Genetic Algorithm:
# Job Sequence: [7, 1, 2, 0, 4, 3, 6, 5]
# Objective Value: 57
# Runtime: 0.1326 seconds
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Machine: 0 |            | Machine: 1 |            | Machine: 2 |            | Machine: 3 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   0 |            | Start:   1 |            | Start:   9 |            | Start:  16 |
# | Job:  7 | Wait:    0 | Proc:    1 | Stop:    1 | Wait:    0 | Proc:    8 | Stop:    9 | Wait:    0 | Proc:    7 | Stop:   16 | Wait:    0 | Proc:    4 | Stop:   20 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    1 |            | Idle:    1 |            | Idle:    2 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   1 |            | Start:   9 |            | Start:  16 |            | Start:  22 |
# | Job:  1 | Wait:    0 | Proc:    7 | Stop:    8 | Wait:    0 | Proc:    5 | Stop:   14 | Wait:    0 | Proc:    6 | Stop:   22 | Wait:    0 | Proc:    8 | Stop:   30 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    8 |            | Idle:    1 |            | Idle:    0 |            | Idle:    2 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   8 |            | Start:  14 |            | Start:  22 |            | Start:  30 |
# | Job:  2 | Wait:    0 | Proc:    5 | Stop:   13 | Wait:    0 | Proc:    8 | Stop:   22 | Wait:    0 | Proc:    6 | Stop:   28 | Wait:    0 | Proc:    5 | Stop:   35 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   13 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  13 |            | Start:  22 |            | Start:  31 |            | Start:  37 |
# | Job:  0 | Wait:    0 | Proc:    9 | Stop:   22 | Wait:    0 | Proc:    9 | Stop:   31 | Wait:    0 | Proc:    6 | Stop:   37 | Wait:    0 | Proc:    8 | Stop:   45 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   22 |            | Idle:    0 |            | Idle:    1 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  22 |            | Start:  31 |            | Start:  37 |            | Start:  46 |
# | Job:  4 | Wait:    0 | Proc:    9 | Stop:   31 | Wait:    0 | Proc:    5 | Stop:   36 | Wait:    0 | Proc:    9 | Stop:   46 | Wait:    0 | Proc:    3 | Stop:   49 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   31 |            | Idle:    4 |            | Idle:    6 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  31 |            | Start:  36 |            | Start:  46 |            | Start:  49 |
# | Job:  3 | Wait:    0 | Proc:    1 | Stop:   32 | Wait:    0 | Proc:    4 | Stop:   40 | Wait:    0 | Proc:    3 | Stop:   49 | Wait:    0 | Proc:    2 | Stop:   51 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   32 |            | Idle:    2 |            | Idle:    8 |            | Idle:    1 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  32 |            | Start:  40 |            | Start:  49 |            | Start:  51 |
# | Job:  6 | Wait:    0 | Proc:    6 | Stop:   38 | Wait:    0 | Proc:    1 | Stop:   41 | Wait:    0 | Proc:    1 | Stop:   50 | Wait:    0 | Proc:    3 | Stop:   54 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   38 |            | Idle:    0 |            | Idle:    4 |            | Idle:    3 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  38 |            | Start:  43 |            | Start:  50 |            | Start:  54 |
# | Job:  5 | Wait:    0 | Proc:    5 | Stop:   43 | Wait:    0 | Proc:    3 | Stop:   46 | Wait:    0 | Proc:    1 | Stop:   51 | Wait:    0 | Proc:    3 | Stop:   57 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
#
#
#
#
# Comparing for N_JOBS = 9 with Genetic Algorithm:
# Job Sequence: [7, 1, 8, 0, 2, 6, 5, 4, 3]
# Objective Value: 63
# Runtime: 0.1401 seconds
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Machine: 0 |            | Machine: 1 |            | Machine: 2 |            | Machine: 3 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   0 |            | Start:   1 |            | Start:   9 |            | Start:  16 |
# | Job:  7 | Wait:    0 | Proc:    1 | Stop:    1 | Wait:    0 | Proc:    8 | Stop:    9 | Wait:    0 | Proc:    7 | Stop:   16 | Wait:    0 | Proc:    4 | Stop:   20 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    1 |            | Idle:    1 |            | Idle:    2 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   1 |            | Start:   9 |            | Start:  16 |            | Start:  22 |
# | Job:  1 | Wait:    0 | Proc:    7 | Stop:    8 | Wait:    0 | Proc:    5 | Stop:   14 | Wait:    0 | Proc:    6 | Stop:   22 | Wait:    0 | Proc:    8 | Stop:   30 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    8 |            | Idle:    5 |            | Idle:    0 |            | Idle:    4 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   8 |            | Start:  14 |            | Start:  23 |            | Start:  30 |
# | Job:  8 | Wait:    0 | Proc:    1 | Stop:    9 | Wait:    0 | Proc:    9 | Stop:   23 | Wait:    0 | Proc:    3 | Stop:   26 | Wait:    0 | Proc:    9 | Stop:   39 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    9 |            | Idle:    5 |            | Idle:    0 |            | Idle:    1 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   9 |            | Start:  23 |            | Start:  32 |            | Start:  39 |
# | Job:  0 | Wait:    0 | Proc:    9 | Stop:   18 | Wait:    0 | Proc:    9 | Stop:   32 | Wait:    0 | Proc:    6 | Stop:   38 | Wait:    0 | Proc:    8 | Stop:   47 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   18 |            | Idle:    9 |            | Idle:    0 |            | Idle:    1 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  18 |            | Start:  32 |            | Start:  40 |            | Start:  47 |
# | Job:  2 | Wait:    0 | Proc:    5 | Stop:   23 | Wait:    0 | Proc:    8 | Stop:   40 | Wait:    0 | Proc:    6 | Stop:   46 | Wait:    0 | Proc:    5 | Stop:   52 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   23 |            | Idle:   11 |            | Idle:    5 |            | Idle:    5 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  23 |            | Start:  40 |            | Start:  46 |            | Start:  52 |
# | Job:  6 | Wait:    0 | Proc:    6 | Stop:   29 | Wait:    0 | Proc:    1 | Stop:   41 | Wait:    0 | Proc:    1 | Stop:   47 | Wait:    0 | Proc:    3 | Stop:   55 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   29 |            | Idle:    7 |            | Idle:    3 |            | Idle:    7 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  29 |            | Start:  41 |            | Start:  47 |            | Start:  55 |
# | Job:  5 | Wait:    0 | Proc:    5 | Stop:   34 | Wait:    0 | Proc:    3 | Stop:   44 | Wait:    0 | Proc:    1 | Stop:   48 | Wait:    0 | Proc:    3 | Stop:   58 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   34 |            | Idle:    1 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  34 |            | Start:  44 |            | Start:  49 |            | Start:  58 |
# | Job:  4 | Wait:    0 | Proc:    9 | Stop:   43 | Wait:    0 | Proc:    5 | Stop:   49 | Wait:    0 | Proc:    9 | Stop:   58 | Wait:    0 | Proc:    3 | Stop:   61 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   43 |            | Idle:    5 |            | Idle:    5 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  43 |            | Start:  49 |            | Start:  58 |            | Start:  61 |
# | Job:  3 | Wait:    0 | Proc:    1 | Stop:   44 | Wait:    0 | Proc:    4 | Stop:   53 | Wait:    0 | Proc:    3 | Stop:   61 | Wait:    0 | Proc:    2 | Stop:   63 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
#
#
#
#
# Comparing for N_JOBS = 10 with Genetic Algorithm:
# Job Sequence: [9, 8, 1, 2, 0, 6, 4, 5, 7, 3]
# Objective Value: 69
# Runtime: 0.1495 seconds
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Machine: 0 |            | Machine: 1 |            | Machine: 2 |            | Machine: 3 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   0 |            | Start:   1 |            | Start:   8 |            | Start:  14 |
# | Job:  9 | Wait:    0 | Proc:    1 | Stop:    1 | Wait:    0 | Proc:    7 | Stop:    8 | Wait:    0 | Proc:    6 | Stop:   14 | Wait:    0 | Proc:    8 | Stop:   22 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    1 |            | Idle:    6 |            | Idle:    0 |            | Idle:    2 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   1 |            | Start:   8 |            | Start:  17 |            | Start:  22 |
# | Job:  8 | Wait:    0 | Proc:    1 | Stop:    2 | Wait:    0 | Proc:    9 | Stop:   17 | Wait:    0 | Proc:    3 | Stop:   20 | Wait:    0 | Proc:    9 | Stop:   31 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    2 |            | Idle:    8 |            | Idle:    0 |            | Idle:    3 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   2 |            | Start:  17 |            | Start:  22 |            | Start:  31 |
# | Job:  1 | Wait:    0 | Proc:    7 | Stop:    9 | Wait:    0 | Proc:    5 | Stop:   22 | Wait:    0 | Proc:    6 | Stop:   28 | Wait:    0 | Proc:    8 | Stop:   39 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    9 |            | Idle:    8 |            | Idle:    0 |            | Idle:    3 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   9 |            | Start:  22 |            | Start:  30 |            | Start:  39 |
# | Job:  2 | Wait:    0 | Proc:    5 | Stop:   14 | Wait:    0 | Proc:    8 | Stop:   30 | Wait:    0 | Proc:    6 | Stop:   36 | Wait:    0 | Proc:    5 | Stop:   44 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   14 |            | Idle:    7 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  14 |            | Start:  30 |            | Start:  39 |            | Start:  45 |
# | Job:  0 | Wait:    0 | Proc:    9 | Stop:   23 | Wait:    0 | Proc:    9 | Stop:   39 | Wait:    0 | Proc:    6 | Stop:   45 | Wait:    0 | Proc:    8 | Stop:   53 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   23 |            | Idle:   10 |            | Idle:    5 |            | Idle:    7 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  23 |            | Start:  39 |            | Start:  45 |            | Start:  53 |
# | Job:  6 | Wait:    0 | Proc:    6 | Stop:   29 | Wait:    0 | Proc:    1 | Stop:   40 | Wait:    0 | Proc:    1 | Stop:   46 | Wait:    0 | Proc:    3 | Stop:   56 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   29 |            | Idle:    2 |            | Idle:    1 |            | Idle:    1 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  29 |            | Start:  40 |            | Start:  46 |            | Start:  56 |
# | Job:  4 | Wait:    0 | Proc:    9 | Stop:   38 | Wait:    0 | Proc:    5 | Stop:   45 | Wait:    0 | Proc:    9 | Stop:   55 | Wait:    0 | Proc:    3 | Stop:   59 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   38 |            | Idle:    2 |            | Idle:    7 |            | Idle:    3 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  38 |            | Start:  45 |            | Start:  55 |            | Start:  59 |
# | Job:  5 | Wait:    0 | Proc:    5 | Stop:   43 | Wait:    0 | Proc:    3 | Stop:   48 | Wait:    0 | Proc:    1 | Stop:   56 | Wait:    0 | Proc:    3 | Stop:   62 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   43 |            | Idle:    4 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  43 |            | Start:  48 |            | Start:  56 |            | Start:  63 |
# | Job:  7 | Wait:    0 | Proc:    1 | Stop:   44 | Wait:    0 | Proc:    8 | Stop:   56 | Wait:    0 | Proc:    7 | Stop:   63 | Wait:    0 | Proc:    4 | Stop:   67 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:   44 |            | Idle:   11 |            | Idle:    3 |            | Idle:    1 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  44 |            | Start:  56 |            | Start:  63 |            | Start:  67 |
# | Job:  3 | Wait:    0 | Proc:    1 | Stop:   45 | Wait:    0 | Proc:    4 | Stop:   60 | Wait:    0 | Proc:    3 | Stop:   66 | Wait:    0 | Proc:    2 | Stop:   69 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
